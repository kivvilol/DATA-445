# %%
# 1) We would use a k-means clustering algorithm because it is both clustering and unsupervised.

# 2) Spam detection is a supervised problem because you have to feed the algorithm data on what is considered spam initially.

# 3) A test set is a smaller portion of our total data that we test our model on after training it in order to determine the performance of the model.

# 4) E

# %%
import pandas as pd
import numpy as np

# reading csv file
house_price = pd.read_csv('Real_Estate.csv')
house_price.head()

# dropping no and transaction date columns
house_price = house_price.drop(columns = ['No', 'transaction_date'])
house_price.head()

# splitting data into training and testing
from sklearn.model_selection import train_test_split # importing train_test_split

X = house_price[['house_age', 'distance_to_the_nearest_MRT_station', 'number_of_convenience_stores', 'latitude', 'longitude']]
Y = house_price['house_price_of_unit_area']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# building the linear model
from sklearn.linear_model import LinearRegression

lm_md = LinearRegression().fit(X_train, Y_train)
lm_md.coef_

# predicting on test
preds = lm_md.predict(X_test)
preds

# calculating the mean square error (MSE) 
mse = np.mean(np.power(preds - Y_test, 2))
mse

# building the second linear model #2
X2 = house_price[['house_age', 'number_of_convenience_stores', 'latitude', 'longitude']]
Y2 = house_price['house_price_of_unit_area']

X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2, Y2, test_size = 0.2)

# building the linear model #2
lm_md2 = LinearRegression().fit(X_train2, Y_train2)
lm_md2.coef_

# predicting on test #2
preds2 = lm_md2.predict(X_test2)
preds2

# calculating the mean square error (MSE) #2
mse2 = np.mean(np.power(preds2 - Y_test2, 2))
mse2

## We would use the second model because it has a smaller mean square error.

# %%
i = 1
while i <= 100:
    
    X = house_price[['house_age', 'distance_to_the_nearest_MRT_station', 'number_of_convenience_stores', 'latitude', 'longitude']]
    Y = house_price['house_price_of_unit_area']

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

    # building the linear model
    from sklearn.linear_model import LinearRegression
    
    lm_md = LinearRegression().fit(X_train, Y_train)
    lm_md.coef_

    # predicting on test
    preds = lm_md.predict(X_test)
    preds

    # calculating the mean square error (MSE) 
    mse = np.mean(np.power(preds - Y_test, 2))
    mse

    # building the second linear model #2
    X3 = house_price[['house_age', 'number_of_convenience_stores', 'latitude', 'longitude']]
    Y3 = house_price['house_price_of_unit_area']

    X_train3, X_test3, Y_train3, Y_test3 = train_test_split(X3, Y3, test_size = 0.2)

    # building the linear model #2
    lm_md3 = LinearRegression().fit(X_train3, Y_train3)
    lm_md3.coef_

    # predicting on test #2
    preds3 = lm_md2.predict(X_test2)
    preds3

    # calculating the mean square error (MSE) #2
    mse3 = np.mean(np.power(preds3 - Y_test3, 2))
    mse3

    i + 1
    
## Our second model still has a lower MSE, so we would want to choose the second model.
